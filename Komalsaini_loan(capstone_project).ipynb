# %% [markdown]
# <a href="https://colab.research.google.com/github/Komalsaini123/Komalsaini123/blob/main/Komalsaini_loan(capstone_project).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
loan_train = pd.read_csv(r"/content/loan.csv")
loan_train
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_train.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
loan_train.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
loan_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
loan_train.shape
# Out:
# (614, 13)

# %%
loan_train.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
loan_train.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
loan_train.isnull()
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      False   False    False       False      False          False
# 1      False   False    False       False      False          False
# 2      False   False    False       False      False          False
# 3      False   False    False       False      False          False
# 4      False   False    False       False      False          False
# ..       ...     ...      ...         ...        ...            ...
# 609    False   False    False       False      False          False
# 610    False   False    False       False      False          False
# 611    False   False    False       False      False          False
# 612    False   False    False       False      False          False
# 613    False   False    False       False      False          False
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              False              False        True             False
# ...

# %%
loan_train.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
numerical_feature_columns = pd.DataFrame(loan_train._get_numeric_data().columns)
numerical_feature_columns
# Out:
#                    0
# 0    ApplicantIncome
# 1  CoapplicantIncome
# 2         LoanAmount
# 3   Loan_Amount_Term
# 4     Credit_History

# %%
categorical_feature_columns = pd.DataFrame(set(loan_train.columns) - set(loan_train._get_numeric_data().columns))
categorical_feature_columns
# Out:
#                0
# 0  Self_Employed
# 1        Loan_ID
# 2    Loan_Status
# 3         Gender
# 4        Married
# 5     Dependents
# 6  Property_Area
# 7      Education

# %%
loan_train.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
loan_train['Gender']= loan_train['Gender'].fillna(loan_train['Gender'].mode()[0])
loan_train['Dependents']= loan_train['Dependents'].fillna(loan_train['Dependents'].mode()[0])
loan_train['Self_Employed']= loan_train['Self_Employed'].fillna(loan_train['Self_Employed'].mode()[0])

# %%
loan_train['LoanAmount']= loan_train['LoanAmount'].fillna(loan_train['LoanAmount'].mean())
loan_train['Loan_Amount_Term']= loan_train['Loan_Amount_Term'].fillna(loan_train['Loan_Amount_Term'].mean())
loan_train['Credit_History']= loan_train['Credit_History'].fillna(loan_train['Credit_History'].mean())

# %%
loan_train.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              3
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(10,6))
sns.countplot(loan_train['Education'],palette ='RdYlGn')
plt.title('Eductional Background',fontsize =20)
plt.xlabel('Education',fontsize=15)
plt.ylabel('Count',fontsize=15)
plt.xticks(color = 'r')
plt.yticks(color = 'r')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# (array([  0., 100., 200., 300., 400., 500., 600.]),
#  <a list of 7 Text major ticklabel objects>)

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(10,6))
sns.countplot(loan_train['Gender'],palette ='RdYlGn')
plt.title('Male Vs Female Count',fontsize =20)
plt.xlabel('Gender',fontsize=15)
plt.ylabel('Count',fontsize=15)
plt.xticks(color = 'r')
plt.yticks(color = 'r')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# (array([  0., 100., 200., 300., 400., 500., 600.]),
#  <a list of 7 Text major ticklabel objects>)

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(10,6))
sns.countplot(loan_train['Married'],palette ='RdYlGn')
plt.title('Marriage Status',fontsize =20)
plt.xlabel('Married',fontsize=15)
plt.ylabel('Count',fontsize=15)
plt.xticks(color = 'r')
plt.yticks(color = 'r')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# (array([  0.,  50., 100., 150., 200., 250., 300., 350., 400., 450.]),
#  <a list of 10 Text major ticklabel objects>)

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(10,6))
sns.countplot(loan_train['Dependents'])
plt.title('Number of Dependents',fontsize =20)
plt.xlabel('Dependents',fontsize=15)
plt.ylabel('Count',fontsize=15)
plt.xticks(color = 'r')
plt.yticks(color = 'r')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# (array([  0.,  50., 100., 150., 200., 250., 300., 350., 400.]),
#  <a list of 9 Text major ticklabel objects>)

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(10,6))
sns.countplot(loan_train['Property_Area'])
plt.title('Mortage Area',fontsize =20)
plt.xlabel('Property_Area',fontsize=15)
plt.ylabel('Count',fontsize=15)
plt.xticks(color = 'r')
plt.yticks(color = 'r')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# (array([  0.,  50., 100., 150., 200., 250.]),
#  <a list of 6 Text major ticklabel objects>)

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(10,6))
sns.countplot(loan_train['Self_Employed'])
plt.title('Employment',fontsize =20)
plt.xlabel('Self_Employed',fontsize=15)
plt.ylabel('Count',fontsize=15)
plt.xticks(color = 'r')
plt.yticks(color = 'r')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# (array([  0., 100., 200., 300., 400., 500., 600.]),
#  <a list of 7 Text major ticklabel objects>)

# %%
plt.figure(figsize=(10,6))
sns.heatmap(loan_train.corr(), cmap='gist_ncar')

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(12,8))
x= loan_train['ApplicantIncome']
y = loan_train['Loan_Amount_Term']
plt.xlabel('Term in months')
plt.ylabel("Applicant's Income")
plt.scatter(x,y, color = 'r', marker ='o')

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(12,8))
x= loan_train['LoanAmount']
y = loan_train['Loan_Amount_Term']
plt.xlabel('Loan Amount')
plt.ylabel('Term in months')
plt.scatter(x,y, color = 'r', marker ='o')

# %%
sns.lmplot('ApplicantIncome', 'CoapplicantIncome', data = loan_train,fit_reg = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.jointplot('ApplicantIncome', 'CoapplicantIncome', data = loan_train, kind = 'hex')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.jointplot('ApplicantIncome', 'CoapplicantIncome', data = loan_train, kind = 'reg')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(15,8))
plt.xticks(rotation= 45)
sns.boxplot('LoanAmount', 'Gender', data = loan_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(15,8))
plt.xticks(rotation= 45)
sns.boxplot('LoanAmount', 'Education', data = loan_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(15,8))
plt.xticks(rotation= 45)
sns.boxplot('LoanAmount', 'Property_Area', data = loan_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(15,8))
plt.xticks(rotation= 45)
sns.boxplot('LoanAmount', 'Self_Employed', data = loan_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(15,8))
plt.xticks(rotation= 45)
sns.boxplot('LoanAmount', 'Married', data = loan_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(15,8))
plt.xticks(rotation= 45)
sns.boxplot('LoanAmount', 'Dependents', data = loan_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
crosstab = pd.crosstab(index=loan_train['Property_Area'], columns=loan_train['Dependents'])
crosstab
# Out:
# Dependents       0   1   2  3+
# Property_Area
# Rural          111  21  29  18
# Semiurban      136  40  37  20
# Urban          113  41  35  13

# %%
lc = pd.crosstab(loan_train['Credit_History'], loan_train['Loan_Status'])
lc.plot(kind='bar', stacked=True, color=['red','blue'], grid=False)

# %%
sns.distplot(loan_train['ApplicantIncome'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(loan_train['CoapplicantIncome'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
loan_train.plot(figsize=(16,10))
plt.show()

# %%
plt.figure(figsize=(16, 10))
plt.grid('darkgrid')
plt.scatter(loan_train['ApplicantIncome'] , loan_train['LoanAmount'], c='r', marker='x')
plt.title("Income vs Loan Amount", fontsize = 15)
plt.xlabel("Applicant's Income", fontsize = 13)
plt.ylabel("Loan Amount", fontsize = 13)
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.show()

# %%
sns.displot(loan_train['Loan_Amount_Term'], color = 'r', alpha = .6)
plt.show()

# %%
sns.displot(loan_train['Credit_History'], color = 'r', alpha = .6)

# %%
sns.pairplot(loan_train)

# %%
sns.barplot(x = "ApplicantIncome", y = "Loan_Status", data = loan_train, hue = "Property_Area")

# %%
sns.barplot(x = "ApplicantIncome",y = "Education",data = loan_train, hue = "Dependents")

# %%
loan_train["Loan_Status"].value_counts()
# Out:
# Y    422
# N    192
# Name: Loan_Status, dtype: int64

# %%
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.preprocessing import LabelEncoder
categorical_column = ['Gender','Married','Dependents','Education','Self_Employed','Property_Area','Loan_Status']
le = LabelEncoder()
for i in categorical_column:
    loan_train[i] = le.fit_transform(loan_train[i])
loan_train.head()
# Out:
#     Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0  LP001002       1        0           0          0              0
# 1  LP001003       1        1           1          0              0
# 2  LP001005       1        1           0          0              1
# 3  LP001006       1        1           0          1              0
# 4  LP001008       1        0           0          0              0
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#    Credit_History  Property_Area  Loan_Status
# 0             1.0              2            1
# 1             1.0              0            0
# ...

# %%
x_train = loan_train.drop(["Loan_Status"], axis= 1)
xtrain = loan_train.drop(['Loan_ID'], axis= 1)
ytrain = loan_train["Loan_Status"]

# %%
x_train,x_test,y_train,y_test = train_test_split(xtrain,ytrain,test_size=0.2)

# %%
reg = LogisticRegression()
reg.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
reg.coef_
# Out:
# array([[-1.29848587e-01,  5.37300535e-01, -4.01645538e-01,
#         -7.25923589e-01,  9.95728544e-02, -5.66150876e-07,
#         -7.57177649e-05, -3.56964049e-03, -9.69281448e-03,
#          2.21228176e+00, -2.24309216e-01,  6.29296225e+00]])

# %%
reg.intercept_
# Out:
# array([-0.0954294])

# %%
reg.score(x_test,y_test)*100
# Out:
# 100.0
